# %%
#for check the which gpu is alloted to you
# !nvidia-smi
# Out:
# Sun Dec 31 16:48:03 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# for Clone from ultralytics
# !git clone https://github.com/ultralytics/ultralytics.git  # clone
# %cd yolov8

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.6/78.2 GB disk)

# %%
# install indep. & clone of Dataset form Roboflow

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="RAYeRP3GxCTGRfUCIKN0")
project = rf.workspace("chocolate-detection").project("chocolate-detection-41qji")
dataset = project.version(1).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 19.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 18.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/chocolate-detection-1/data.yaml epochs=500 imgsz=640 lr0=0.01
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#validate custom model
# !yolo task=detect mode=val model=/content/runs/detect/train9/weights/best.pt data=/content/chocolate-detection-1/data.yaml
# Out:
# 2023-12-31 19:23:39.521041: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-31 19:23:39.521081: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-31 19:23:39.522321: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-31 19:23:40.558877: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients, 28.4 GFLOPs
# ...

# %%
#Testing with Custom Model
# !yolo task=detect mode=predict model=/content/runs/detect/train9/weights/best.pt conf=0.25 source=/content/chocolate-detection-1/test/images save=True
# Out:
# 2023-12-31 19:26:05.374296: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-31 19:26:05.374356: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-31 19:26:05.376099: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-31 19:26:06.801090: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients, 28.4 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# ...

# %%
# !zip -r final_yolov8s_traing.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/predict/ (stored 0%)
#   adding: content/runs/detect/predict/mars-19-_jpg.rf.078a7bd2d40c3cb59e8b46c914a8420d.jpg (deflated 5%)
#   adding: content/runs/detect/predict/kitkat-39-_jpg.rf.62acb16a0d364ec75a75ac646390f96b.jpg (deflated 8%)
#   adding: content/runs/detect/predict/cadbury-19-_jpg.rf.9169c471957e33036c5f631a520aa291.jpg (deflated 6%)
#   adding: content/runs/detect/predict/snickers-16-_jpg.rf.ef94c28ea68ed9371f59d8c93c666e84.jpg (deflated 18%)
#   adding: content/runs/detect/predict/mars-3-_jpg.rf.9029a874d3f36709b4ea702fc1ab2b41.jpg (deflated 6%)
#   adding: content/runs/detect/predict/cadbury-6-_jpg.rf.3b5fe44c8d2238097a66f699a7dba7ca.jpg (deflated 5%)
#   adding: content/runs/detect/predict/cadbury-27-_jpg.rf.c29793b74e955ace491f71204edfceb3.jpg (deflated 5%)
# ...
